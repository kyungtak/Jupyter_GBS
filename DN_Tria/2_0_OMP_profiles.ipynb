# %% [markdown]
# <div class="alert alert-block alert-info">
# <span style="font-size: 26px;"><b> Radial OMP profiles comparison </b></span><br><br>
#
# <span style="font-size: 16px;">
# - In this script, radial profiles of PT/NT DN plasmas are compared. <br>
# - NT plasma is known to confine better than PT. <br>
# - Electron pressure profile seems a good quantity for this comparison
#
# </span>
# </div>

# %%
import gbspy as g
import numpy as np
import matplotlib.pyplot as plt
import os
import multiprocessing as mp
from matplotlib.animation import FuncAnimation
from scipy.interpolate import griddata
from mpl_toolkits.axes_grid1 import make_axes_locatable
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes
from mpl_toolkits.axes_grid1.inset_locator import mark_inset
from matplotlib.ticker import AutoMinorLocator
import matplotlib.lines as mlines
from matplotlib.ticker import AutoMinorLocator
from scipy.interpolate import RectBivariateSpline
# Get the current working directory|
cwd = os.getcwd()
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
plt.rcdefaults()  # Reset to default settings

# %%
# IEEE journals typically require figures to be very clear at a column width of around 3.5 to 4 inches
fig_width = 3.5  # in inches

plt.rcParams.update({
    # Figure size and DPI
    'figure.figsize': (fig_width, fig_width / 1.618),  # IEEE column width, golden ratio height
    'figure.dpi': 300,                     # Figure resolution
    'savefig.dpi': 300,                    # Save figure resolution
    'savefig.format': 'pdf',               # Preferred format for vector graphics

    # Font settings
    'font.size': 10,                       # Main font size
    'font.family': 'sans-serif',           # Font family
    'font.sans-serif': ['Arial', 'Helvetica', 'DejaVu Sans'],  # Font type

    # Axes settings
    'axes.labelsize': 10,                  # Font size of the x and y labels
    'axes.titlesize': 10,                  # Font size of the title
    'axes.linewidth': 1,                   # Edge line width

    # Tick settings
    'xtick.labelsize': 8,                  # Font size of the x tick labels
    'ytick.labelsize': 8,                  # Font size of the y tick labels
    'xtick.major.size': 4,                 # Length of major tick marks
    'xtick.minor.size': 2,                 # Length of minor tick marks
    'xtick.major.width': 1,                # Width of major tick marks
    'xtick.minor.width': 0.5,              # Width of minor tick marks
    'ytick.major.size': 4,                 # Length of major tick marks
    'ytick.minor.size': 2,                 # Length of minor tick marks
    'ytick.major.width': 1,                # Width of major tick marks
    'ytick.minor.width': 0.5,              # Width of minor tick marks

    # Legend settings
    'legend.fontsize': 8,                  # Font size of the legend
    'legend.frameon': True,               # Disable background frame
    'legend.edgecolor':'white',

    # Line settings
    'lines.linewidth': 1.5,                # Line width
    'lines.markersize': 5,                 # Marker size

    # Grid settings
    'grid.alpha': 0.5,                     # Grid line transparency
    'grid.linestyle': ':',                 # Grid line style

})

# %%
os.chdir('/marconi/home/userexternal/klim0000/scratch/GBS/DN_tria/delta_scan/DNT_dn0p3')
s=g.Sim()
# Diagnostic time
t_final = s.time[-1]; t_init = t_final -10

pe = s.get_field('pe', t1=t_init, t2=t_final)
dens = s.get_field('n', t1=t_init, t2=t_final)
Te = s.get_field('Te', t1=t_init, t2=t_final)

pe_avg_DNT_dn0p3 = np.mean(pe, axis=(2,3))
dens_avg_DNT_dn0p3 = np.mean(dens, axis=(2,3))
Te_avg_DNT_dn0p3 = np.mean(Te, axis=(2,3))

os.chdir('/marconi/home/userexternal/klim0000/scratch/GBS/DN_tria/delta_scan/DPT_d0p3')
s=g.Sim()
# Diagnostic time
t_final = s.time[-1]; t_init = t_final -10
pe = s.get_field('pe', t1=t_init, t2=t_final)
dens = s.get_field('n', t1=t_init, t2=t_final)
Te = s.get_field('Te', t1=t_init, t2=t_final)

pe_avg_DPT_d0p3 = np.mean(pe, axis=(2,3))
dens_avg_DPT_d0p3 = np.mean(dens, axis=(2,3))
Te_avg_DPT_d0p3 = np.mean(Te, axis=(2,3))
# Out:
# /marconi/home/userexternal/klim0000/miniconda3/lib/python3.9/site-packages/gbs_python/gbspy/pp.py:65: FutureWarning: An error has occured when reading the result index from the HDF5 contents:
#
# Traceback (most recent call last):
#   File "/marconi/home/userexternal/klim0000/miniconda3/lib/python3.9/site-packages/gbs_python/gbspy/pp.py", line 58, in _read_file_index_from_result
#     with h5py.File(path, "r") as f:
#   File "/marconi/home/userexternal/klim0000/miniconda3/lib/python3.9/site-packages/h5py/_hl/files.py", line 533, in __init__
#     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#   File "/marconi/home/userexternal/klim0000/miniconda3/lib/python3.9/site-packages/h5py/_hl/files.py", line 226, in make_fid
#     fid = h5f.open(name, flags, fapl=fapl)
#   File "h5py/_objects.pyx", line 54, in h5py._objects.with_phil.wrapper
#   File "h5py/_objects.pyx", line 55, in h5py._objects.with_phil.wrapper
#   File "h5py/h5f.pyx", line 106, in h5py.h5f.open
# ...

# %%
os.chdir('/marconi/home/userexternal/klim0000/scratch/GBS/DN_tria/delta_scan/DNT_dn0p4')
s=g.Sim()
# Diagnostic time
t_final = s.time[-1]; t_init = t_final -10

pe = s.get_field('pe', t1=t_init, t2=t_final)
dens = s.get_field('n', t1=t_init, t2=t_final)
Te = s.get_field('Te', t1=t_init, t2=t_final)

pe_avg_DNT_dn0p4 = np.mean(pe, axis=(2,3))
dens_avg_DNT_dn0p4 = np.mean(dens, axis=(2,3))
Te_avg_DNT_dn0p4 = np.mean(Te, axis=(2,3))

os.chdir('/marconi/home/userexternal/klim0000/scratch/GBS/DN_tria/delta_scan/DPT_d0p4')
s=g.Sim()
# Diagnostic time
t_final = s.time[-1]; t_init = t_final -10
pe = s.get_field('pe', t1=t_init, t2=t_final)
dens = s.get_field('n', t1=t_init, t2=t_final)
Te = s.get_field('Te', t1=t_init, t2=t_final)

pe_avg_DPT_d0p4 = np.mean(pe, axis=(2,3))
dens_avg_DPT_d0p4 = np.mean(dens, axis=(2,3))
Te_avg_DPT_d0p4 = np.mean(Te, axis=(2,3))
# Out:
# An error occured when opening /marconi_scratch/userexternal/klim0000/GBS/DN_tria/delta_scan/DPT_d0p4/results_51.h5:
# Unable to open file (file signature not found)
# Trying to skip the file...
# Last results file skipped

# %%
os.chdir('/marconi/home/userexternal/klim0000/scratch/GBS/DN_tria/delta_scan/DNT_dn0p5')
s=g.Sim()
# Diagnostic time
t_final = s.time[-1]; t_init = t_final -10

pe = s.get_field('pe', t1=t_init, t2=t_final)
dens = s.get_field('n', t1=t_init, t2=t_final)
Te = s.get_field('Te', t1=t_init, t2=t_final)

pe_avg_DNT_dn0p5 = np.mean(pe, axis=(2,3))
dens_avg_DNT_dn0p5 = np.mean(dens, axis=(2,3))
Te_avg_DNT_dn0p5 = np.mean(Te, axis=(2,3))

os.chdir('/marconi/home/userexternal/klim0000/scratch/GBS/DN_tria/delta_scan/DPT_d0p5')
s=g.Sim()
# Diagnostic time
t_final = s.time[-1]; t_init = t_final -10

pe = s.get_field('pe', t1=t_init, t2=t_final)
dens = s.get_field('n', t1=t_init, t2=t_final)
Te = s.get_field('Te', t1=t_init, t2=t_final)

pe_avg_DPT_d0p5 = np.mean(pe, axis=(2,3))
dens_avg_DPT_d0p5 = np.mean(dens, axis=(2,3))
Te_avg_DPT_d0p5 = np.mean(Te, axis=(2,3))

# %%
os.chdir('/marconi/home/userexternal/klim0000/scratch/GBS/DN_tria/delta_scan/DNT_dn0p6')
s=g.Sim()
# Diagnostic time
t_final = s.time[-1]; t_init = t_final

pe = s.get_field('pe', t1=t_init, t2=t_final)
dens = s.get_field('n', t1=t_init, t2=t_final)
Te = s.get_field('Te', t1=t_init, t2=t_final)
Te = s.get_field('strmf', t1=t_init, t2=t_final)

pe_avg_DNT_dn0p6 = np.mean(pe, axis=(2,3))
dens_avg_DNT_dn0p6 = np.mean(dens, axis=(2,3))
Te_avg_DNT_dn0p6 = np.mean(Te, axis=(2,3))
phi_avg_DNT_dn0p6 = np.mean(phi, axis=(2,3))

os.chdir('/marconi/home/userexternal/klim0000/scratch/GBS/DN_tria/delta_scan/DPT_d0p6')
s=g.Sim()
# Diagnostic time
t_final = s.time[-1]; t_init = t_final 

pe = s.get_field('pe', t1=t_init, t2=t_final)
dens = s.get_field('n', t1=t_init, t2=t_final)
Te = s.get_field('Te', t1=t_init, t2=t_final)
phi = s.get_field('strmf', t1=t_init, t2=t_final)

pe_avg_DPT_d0p6 = np.mean(pe, axis=(2,3))
dens_avg_DPT_d0p6 = np.mean(dens, axis=(2,3))
Te_avg_DPT_d0p6 = np.mean(Te, axis=(2,3))
phi_avg_DPT_d0p6 = np.mean(phi, axis=(2,3))

# %% [markdown]
# <div class="alert alert-block alert-info" style="text-align: center;">
# <span style="font-size: 40px;"><b> Figures </b></span><br><br>
# <span style="font-size: 16px;">
# - PT 0.6 separatrix x=510 <br>
# - NT -0.6 separatrix x=420 <br>
# </div>

# %%
fig_width = 3.5  # IEEE column width in inches
fig_height = fig_width / 1.618  # Golden ratio height for a single subplot
x_coord = np.linspace(0,600,s.nx)
#fig, axes = plt.subplots(ncols=2, figsize=(2*fig_width, 3.5), sharey=True)
fig, axes = plt.subplots(ncols=2, figsize=(1.7*fig_width, fig_height), sharey=True)
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.1, hspace=None)

plt.rcParams.update({
    'font.family': 'sans-serif', #helvetica, sans-serif
    #'text.usetex': True,  # Use this only if LaTeX is installed and configured
})

axes[0].plot(x_coord, pe_avg_DNT_dn0p6[s.iy0][:], '-', label=r'$\delta=-0.6$', c='r')
axes[1].plot(x_coord, pe_avg_DPT_d0p6[s.iy0][:], '-', label=r'$\delta=0.6$', c='b')
#axes[0].plot(x_coord, pe_avg_DNT_dn0p5[s.iy0][:],   '-',   label=r'$\delta=-0.5$', c='g')
#axes[0].plot(x_coord, pe_avg_DNT_dn0p6[s.iy0][:],   '-',   label=r'$\delta=-0.6$', c='m')

#axes[1].plot(x_coord, pe_avg_LSN_d40[162][:],   '-', label=r'LSN $\delta R=-40\rho_{s0}$', c='r', )
#axes[1].plot(x_coord, pe_avg_DN_nu0p3[162][:], '-', label=r'DN $\,\,\,\delta R=0$', c='b')
#axes[1].plot(x_coord, pe_avg_USN_d40[162][:], '-',   label=r'USN $\delta R=40\rho_{s0}$', c='g')


for ax in axes:
    ax.grid(True, which='major', lw=0.5)
    #ax.grid(True, which='major', alpha=0.8, linestyle=':', linewidth=0.5)
    ax.xaxis.set_minor_locator(AutoMinorLocator())
    ax.yaxis.set_minor_locator(AutoMinorLocator())
    ax.tick_params(which='major', direction="in")
    ax.tick_params(which='minor', direction="in")
    #ax.set_xlabel(r'$(r-r_{{sep}})$', rotation=0, size=5, labelpad=1)
    ax.set_xlabel(r'$R/\rho_{s0}$')
    #ax.set_ylabel(r'$n$', rotation=90, size=3, labelpad=1)
    ax.yaxis.get_offset_text().set_fontsize(10)
    # Figure edge setting
    ax.spines["bottom"].set_linewidth(1)
    ax.spines["left"].set_linewidth(1)
    ax.spines["right"].set_linewidth(1)
    ax.spines["top"].set_linewidth(1)

axes[0].axvline(x=420, lw=1, c='k', ls='--')
axes[1].axvline(x=510, lw=1, c='k', ls='--')

axes[0].set_title(r'$p_e/p_0$')
axes[1].set_title(r'$p_e/p_0$')

axes[0].legend(bbox_to_anchor=(1., 1), loc='upper right', facecolor='white', framealpha=1)
axes[1].legend(bbox_to_anchor=(1., 1), loc='upper right', facecolor='white', framealpha=1 )
#plt.tight_layout()


# Save the figure
dpi_val=300; home_directory = os.path.expanduser('~'); os.chdir(home_directory)
#plt.savefig("OMP_pe.pdf", bbox_inches = 'tight', format='pdf',pad_inches = 0.01, dpi=dpi_val)

# %%
fig_width = 3.5  # IEEE column width in inches
fig_height = fig_width / 1.618  # Golden ratio height for a single subplot
x_coord = np.linspace(0,600,s.nx)
#fig, axes = plt.subplots(ncols=2, figsize=(2*fig_width, 3.5), sharey=True)
fig, axes = plt.subplots(ncols=2, figsize=(1.7*fig_width, fig_height), sharey=True)
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.1, hspace=None)

plt.rcParams.update({
    'font.family': 'sans-serif', #helvetica, sans-serif
    #'text.usetex': True,  # Use this only if LaTeX is installed and configured
})

axes[0].plot(x_coord, pe_avg_DNT_dn0p6[s.iy0][:], '-', label=r'$\delta=-0.6$', c='r')
axes[1].plot(x_coord, pe_avg_DPT_d0p6[s.iy0][:], '-', label=r'$\delta=0.6$', c='b')
#axes[0].plot(x_coord, pe_avg_DNT_dn0p5[s.iy0][:],   '-',   label=r'$\delta=-0.5$', c='g')
#axes[0].plot(x_coord, pe_avg_DNT_dn0p6[s.iy0][:],   '-',   label=r'$\delta=-0.6$', c='m')

#axes[1].plot(x_coord, pe_avg_LSN_d40[162][:],   '-', label=r'LSN $\delta R=-40\rho_{s0}$', c='r', )
#axes[1].plot(x_coord, pe_avg_DN_nu0p3[162][:], '-', label=r'DN $\,\,\,\delta R=0$', c='b')
#axes[1].plot(x_coord, pe_avg_USN_d40[162][:], '-',   label=r'USN $\delta R=40\rho_{s0}$', c='g')


for ax in axes:
    ax.grid(True, which='major', lw=0.5)
    #ax.grid(True, which='major', alpha=0.8, linestyle=':', linewidth=0.5)
    ax.xaxis.set_minor_locator(AutoMinorLocator())
    ax.yaxis.set_minor_locator(AutoMinorLocator())
    ax.tick_params(which='major', direction="in")
    ax.tick_params(which='minor', direction="in")
    #ax.set_xlabel(r'$(r-r_{{sep}})$', rotation=0, size=5, labelpad=1)
    ax.set_xlabel(r'$R/\rho_{s0}$')
    #ax.set_ylabel(r'$n$', rotation=90, size=3, labelpad=1)
    ax.yaxis.get_offset_text().set_fontsize(10)
    # Figure edge setting
    ax.spines["bottom"].set_linewidth(1)
    ax.spines["left"].set_linewidth(1)
    ax.spines["right"].set_linewidth(1)
    ax.spines["top"].set_linewidth(1)

axes[0].axvline(x=420, lw=1, c='k', ls='--')
axes[0].set_xlim([400,440]); axes[0].set_ylim([0.,1])


axes[1].axvline(x=510, lw=1, c='k', ls='--')
axes[1].set_xlim([490,530]); axes[0].set_ylim([0.,1])

axes[0].set_title(r'$p_e/p_0$')
axes[1].set_title(r'$p_e/p_0$')

axes[0].legend(bbox_to_anchor=(1., 1), loc='upper right', facecolor='white', framealpha=1)
axes[1].legend(bbox_to_anchor=(1., 1), loc='upper right', facecolor='white', framealpha=1 )
#plt.tight_layout()


# Save the figure
dpi_val=300; home_directory = os.path.expanduser('~'); os.chdir(home_directory)
#plt.savefig("OMP_pe.pdf", bbox_inches = 'tight', format='pdf',pad_inches = 0.01, dpi=dpi_val)

# %%
fig_width = 3.5  # IEEE column width in inches
fig_height = fig_width / 1.618  # Golden ratio height for a single subplot

#fig, axes = plt.subplots(ncols=2, figsize=(2*fig_width, 3.5), sharey=True)
fig, axes = plt.subplots(ncols=3, figsize=(2.4*fig_width, fig_height), sharey=True)
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.1, hspace=None)

plt.rcParams.update({
    'font.family': 'sans-serif', #helvetica, sans-serif
    #'text.usetex': True,  # Use this only if LaTeX is installed and configured
})


axes[0].plot(x_coord, pe_avg_DNT_dn0p3[s.iy0][:], '-', label=r'$\delta=-0.3$', c='r')
axes[0].plot(x_coord, pe_avg_DPT_d0p3[s.iy0][:], '-', label=r'$\delta=0.3$', c='b')

axes[1].plot(x_coord, pe_avg_DNT_dn0p5[s.iy0][:], '-', label=r'$\delta=-0.5$', c='r')
axes[1].plot(x_coord, pe_avg_DPT_d0p5[s.iy0][:], '-', label=r'$\delta=0.5$', c='b')

axes[2].plot(x_coord, pe_avg_DNT_dn0p6[s.iy0][:], '-', label=r'$\delta=-0.6$', c='r')
axes[2].plot(x_coord, pe_avg_DPT_d0p6[s.iy0][:], '-', label=r'$\delta=0.6$', c='b')

for ax in axes:
    ax.grid(True, which='major', lw=0.5)
    #ax.grid(True, which='major', alpha=0.8, linestyle=':', linewidth=0.5)
    ax.xaxis.set_minor_locator(AutoMinorLocator())
    ax.yaxis.set_minor_locator(AutoMinorLocator())
    ax.tick_params(which='major', direction="in")
    ax.tick_params(which='minor', direction="in")
    #ax.set_xlabel(r'$(r-r_{{sep}})$', rotation=0, size=5, labelpad=1)
    ax.set_xlabel(r'$R/\rho_{s0}$')
    #ax.set_ylabel(r'$n$', rotation=90, size=3, labelpad=1)
    ax.yaxis.get_offset_text().set_fontsize(10)
    # Figure edge setting
    ax.spines["bottom"].set_linewidth(1)
    ax.spines["left"].set_linewidth(1)
    ax.spines["right"].set_linewidth(1)
    ax.spines["top"].set_linewidth(1)
    #ax.set_xlim([250, 600])
    #ax.set_ylim([0.1, 1.7])
    ax.axvline(x=470, lw=1, c='k', ls='--')
    #ax.set_yticks(np.arange(0.2, 1.7, 0.4))

axes[0].set_title(r'$p_e/p_0$')
axes[1].set_title(r'$p_e/p_0$')
axes[1].set_title(r'$p_e/p_0$')

axes[2].legend(bbox_to_anchor=(1., 1), loc='upper right', facecolor='white', framealpha=1)
#axes[1].legend(bbox_to_anchor=(1., 1), loc='upper right', facecolor='white', framealpha=1 )
#plt.tight_layout()


# Save the figure
dpi_val=300; home_directory = os.path.expanduser('~'); os.chdir(home_directory)
#plt.savefig("OMP_pe.pdf", bbox_inches = 'tight', format='pdf',pad_inches = 0.01, dpi=dpi_val)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <span style="font-size: 22px;"><b> nu scan </b></span><br>
# </div>

# %%
# DNT
os.chdir('/marconi/home/userexternal/klim0000/scratch/GBS/DN_tria/nu_scan/DNT_nu0p1')
s=g.Sim()
# Diagnostic time
t_final = s.time[-1]; t_init = t_final -10

pe = s.get_field('pe', t1=t_init, t2=t_final)
dens = s.get_field('n', t1=t_init, t2=t_final)
Te = s.get_field('Te', t1=t_init, t2=t_final)

pe_avg_DNT_nu0p1 = np.mean(pe, axis=(2,3))
dens_avg_DNT_nu0p1 = np.mean(dens, axis=(2,3))
Te_avg_DNT_nu0p1 = np.mean(Te, axis=(2,3))

os.chdir('/marconi/home/userexternal/klim0000/scratch/GBS/DN_tria/nu_scan/DNT_nu1')
s=g.Sim()
# Diagnostic time
t_final = s.time[-1]; t_init = t_final -10
pe = s.get_field('pe', t1=t_init, t2=t_final)
dens = s.get_field('n', t1=t_init, t2=t_final)
Te = s.get_field('Te', t1=t_init, t2=t_final)

pe_avg_DNT_nu1 = np.mean(pe, axis=(2,3))
dens_avg_DNT_nu1 = np.mean(dens, axis=(2,3))
Te_avg_DNT_nu1 = np.mean(Te, axis=(2,3))

# %%
# DPT
os.chdir('/marconi/home/userexternal/klim0000/scratch/GBS/DN_tria/nu_scan/DPT_nu0p1')
s=g.Sim()
# Diagnostic time
t_final = s.time[-1]; t_init = t_final -10
pe = s.get_field('pe', t1=t_init, t2=t_final)
dens = s.get_field('n', t1=t_init, t2=t_final)
Te = s.get_field('Te', t1=t_init, t2=t_final)

pe_avg_DPT_nu0p1 = np.mean(pe, axis=(2,3))
dens_avg_DPT_nu0p1 = np.mean(dens, axis=(2,3))
Te_avg_DPT_nu0p1 = np.mean(Te, axis=(2,3))

os.chdir('/marconi/home/userexternal/klim0000/scratch/GBS/DN_tria/nu_scan/DPT_nu1')
s=g.Sim()
# Diagnostic time
t_final = s.time[-1]; t_init = t_final -10
pe = s.get_field('pe', t1=t_init, t2=t_final)
dens = s.get_field('n', t1=t_init, t2=t_final)
Te = s.get_field('Te', t1=t_init, t2=t_final)

pe_avg_DPT_nu1 = np.mean(pe, axis=(2,3))
dens_avg_DPT_nu1 = np.mean(dens, axis=(2,3))
Te_avg_DPT_nu1 = np.mean(Te, axis=(2,3))

# %%
fig_width = 3.5  # IEEE column width in inches
fig_height = fig_width / 1.618  # Golden ratio height for a single subplot

#fig, axes = plt.subplots(ncols=2, figsize=(2*fig_width, 3.5), sharey=True)
fig, axes = plt.subplots(ncols=2, figsize=(1.7*fig_width, fig_height))
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.3, hspace=None)

plt.rcParams.update({
    'font.family': 'sans-serif', #helvetica, sans-serif
    #'text.usetex': True,  # Use this only if LaTeX is installed and configured
})

axes[0].plot(x_coord, pe_avg_DNT_nu0p1[s.iy0][:], '-', label=r'DNT $\nu=0.1$', c='r')
axes[0].plot(x_coord, pe_avg_DNT_dn0p6[s.iy0][:], '-', label=r'DNT $\nu=0.3$', c='b')
axes[0].plot(x_coord, pe_avg_DNT_nu1[s.iy0][:],   '-',   label=r'DNT $\nu=1.0$', c='g')

axes[1].plot(x_coord, pe_avg_DPT_nu0p1[s.iy0][:],   '-', label=r'DPT $\nu=0.1$', c='r', )
axes[1].plot(x_coord, pe_avg_DPT_d0p6[s.iy0][:], '-', label=r'DPT $\nu=0.3$', c='b')
axes[1].plot(x_coord, pe_avg_DPT_nu1[s.iy0][:], '-',   label=r'DPT $\nu=1.0$', c='g')


for ax in axes:
    ax.grid(True, which='major', lw=0.5)
    #ax.grid(True, which='major', alpha=0.8, linestyle=':', linewidth=0.5)
    ax.xaxis.set_minor_locator(AutoMinorLocator())
    ax.yaxis.set_minor_locator(AutoMinorLocator())
    ax.tick_params(which='major', direction="in")
    ax.tick_params(which='minor', direction="in")
    #ax.set_xlabel(r'$(r-r_{{sep}})$', rotation=0, size=5, labelpad=1)
    ax.set_xlabel(r'$R/\rho_{s0}$')
    #ax.set_ylabel(r'$n$', rotation=90, size=3, labelpad=1)
    ax.yaxis.get_offset_text().set_fontsize(10)
    # Figure edge setting
    ax.spines["bottom"].set_linewidth(1)
    ax.spines["left"].set_linewidth(1)
    ax.spines["right"].set_linewidth(1)
    ax.spines["top"].set_linewidth(1)
    #ax.set_xlim([450, 495])
    #ax.set_ylim([0.1, 1.7])
    #ax.axvline(x=470, lw=1, c='k', ls='--')
    #ax.set_yticks(np.arange(0.2, 1.7, 0.4))

axes[0].set_title(r'$p_e/p_0$')
axes[1].set_title(r'$p_e/p_0$')

axes[0].legend(bbox_to_anchor=(1., 1), loc='upper right', facecolor='white', framealpha=1)
axes[1].legend(bbox_to_anchor=(1., 1), loc='upper left', facecolor='white', framealpha=1 )
#plt.tight_layout()


axes[0].set_xlim([300,420]); axes[0].set_ylim([-0.5,8])

# Save the figure
dpi_val=300; home_directory = os.path.expanduser('~'); os.chdir(home_directory)
#plt.savefig("OMP_pe.pdf", bbox_inches = 'tight', format='pdf',pad_inches = 0.01, dpi=dpi_val)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <span style="font-size: 22px;"><b> $S_T$ scan </b></span><br>
# </div>

# %%
# DNT
os.chdir('/marconi/home/userexternal/klim0000/scratch/GBS/DN_tria/st_scan/DNT_st0p05')
s=g.Sim()
# Diagnostic time
t_final = s.time[-1]; t_init = t_final -10

pe = s.get_field('pe', t1=t_init, t2=t_final)
dens = s.get_field('n', t1=t_init, t2=t_final)
Te = s.get_field('Te', t1=t_init, t2=t_final)
phi = s.get_field('strmf', t1=t_init, t2=t_final)

pe_avg_DNT_st0p05 = np.mean(pe, axis=(2,3))
dens_avg_DNT_st0p05 = np.mean(dens, axis=(2,3))
Te_avg_DNT_st0p05 = np.mean(Te, axis=(2,3))
phi_avg_DNT_st0p05 = np.mean(phi, axis=(2,3))

os.chdir('/marconi/home/userexternal/klim0000/scratch/GBS/DN_tria/st_scan/DNT_st0p3')
s=g.Sim()
# Diagnostic time
t_final = s.time[-1]; t_init = t_final -10
pe = s.get_field('pe', t1=t_init, t2=t_final)
dens = s.get_field('n', t1=t_init, t2=t_final)
Te = s.get_field('Te', t1=t_init, t2=t_final)
phi = s.get_field('strmf', t1=t_init, t2=t_final)

pe_avg_DNT_st0p3 = np.mean(pe, axis=(2,3))
dens_avg_DNT_st0p3 = np.mean(dens, axis=(2,3))
Te_avg_DNT_st0p3 = np.mean(Te, axis=(2,3))
phi_avg_DNT_st0p3 = np.mean(phi, axis=(2,3))

# %%
# DPT
os.chdir('/marconi/home/userexternal/klim0000/scratch/GBS/DN_tria/st_scan/DPT_st0p05')
s=g.Sim()
# Diagnostic time
t_final = s.time[-1]; t_init = t_final 
pe = s.get_field('pe', t1=t_init, t2=t_final)
dens = s.get_field('n', t1=t_init, t2=t_final)
Te = s.get_field('Te', t1=t_init, t2=t_final)
phi = s.get_field('strmf', t1=t_init, t2=t_final)


pe_avg_DPT_st0p05 = np.mean(pe, axis=(2,3))
dens_avg_DPT_st0p05 = np.mean(dens, axis=(2,3))
Te_avg_DPT_st0p05 = np.mean(Te, axis=(2,3))
phi_avg_DPT_st0p05 = np.mean(phi, axis=(2,3))

os.chdir('/marconi/home/userexternal/klim0000/scratch/GBS/DN_tria/st_scan/DPT_st0p3')
s=g.Sim()
# Diagnostic time
t_final = s.time[-1]; t_init = t_final 
pe = s.get_field('pe', t1=t_init, t2=t_final)
dens = s.get_field('n', t1=t_init, t2=t_final)
Te = s.get_field('Te', t1=t_init, t2=t_final)
phi = s.get_field('strmf', t1=t_init, t2=t_final)

pe_avg_DPT_st0p3 = np.mean(pe, axis=(2,3))
dens_avg_DPT_st0p3 = np.mean(dens, axis=(2,3))
Te_avg_DPT_st0p3 = np.mean(Te, axis=(2,3))
phi_avg_DPT_st0p3 = np.mean(phi, axis=(2,3))

# %%
fig_width = 3.5  # IEEE column width in inches
fig_height = fig_width / 1.618  # Golden ratio height for a single subplot

#fig, axes = plt.subplots(ncols=2, figsize=(2*fig_width, 3.5), sharey=True)
fig, axes = plt.subplots(ncols=2, figsize=(1.7*fig_width, fig_height), sharey=True)
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.1, hspace=None)

plt.rcParams.update({
    'font.family': 'sans-serif', #helvetica, sans-serif
    #'text.usetex': True,  # Use this only if LaTeX is installed and configured
})

axes[0].plot(x_coord, pe_avg_DNT_st0p3[s.iy0][:],   '-',   label=r'$s_{t0}=0.3$', c='g')
axes[0].plot(x_coord, pe_avg_DNT_dn0p6[s.iy0][:], '-', label=r'$s_{t0}=0.15$', c='b')
axes[0].plot(x_coord, pe_avg_DNT_st0p05[s.iy0][:], '-', label=r'$s_{t0}=0.05$', c='r')


axes[1].plot(x_coord, pe_avg_DPT_st0p3[s.iy0][:], '-',   label=r'$s_{t0}=0.3$', c='g')
axes[1].plot(x_coord, pe_avg_DPT_d0p6[s.iy0][:], '-', label=r'$s_{t0}=0.15$', c='b')
axes[1].plot(x_coord, pe_avg_DPT_st0p05[s.iy0][:],   '-', label=r'$s_{t0}=0.05$', c='r', )




for ax in axes:
    ax.grid(True, which='major', lw=0.5)
    #ax.grid(True, which='major', alpha=0.8, linestyle=':', linewidth=0.5)
    ax.xaxis.set_minor_locator(AutoMinorLocator())
    ax.yaxis.set_minor_locator(AutoMinorLocator())
    ax.tick_params(which='major', direction="in")
    ax.tick_params(which='minor', direction="in")
    #ax.set_xlabel(r'$(r-r_{{sep}})$', rotation=0, size=5, labelpad=1)
    ax.set_xlabel(r'$R/\rho_{s0}$')
    #ax.set_ylabel(r'$n$', rotation=90, size=3, labelpad=1)
    ax.yaxis.get_offset_text().set_fontsize(10)
    # Figure edge setting
    ax.spines["bottom"].set_linewidth(1)
    ax.spines["left"].set_linewidth(1)
    ax.spines["right"].set_linewidth(1)
    ax.spines["top"].set_linewidth(1)
    #ax.set_xlim([450, 495])
    #ax.set_ylim([0.1, 1.7])
    
    #ax.set_yticks(np.arange(0.2, 1.7, 0.4))



axes[0].set_ylabel(r'$p_e/p_0$')
#axes[1].set_ylabel(r'$p_e/p_0$')
axes[0].set_title(r'NT $\delta=-0.6$')
axes[1].set_title(r'PT $\delta=+0.6$')


#axes[0].legend(bbox_to_anchor=(0.5, 1), loc='upper right', facecolor='white', framealpha=1)
axes[1].legend(bbox_to_anchor=(1, 1), loc='upper right', facecolor='white', framealpha=1 )
#plt.tight_layout()

axes[0].axvline(x=420, lw=1, c='k', ls='--')    
axes[1].axvline(x=510, lw=1, c='k', ls='--')

axes[0].set_xlim([210,440]); axes[0].set_ylim([0,50])
axes[1].set_xlim([400,530]); axes[1].set_ylim([0,50])

# Save the figure
dpi_val=300; home_directory = os.path.expanduser('~'); os.chdir(home_directory)
#plt.savefig("OMP_pe.pdf", bbox_inches = 'tight', format='pdf',pad_inches = 0.01, dpi=dpi_val)

# %%
fig_width = 3.5  # IEEE column width in inches
fig_height = fig_width / 1.618  # Golden ratio height for a single subplot

#fig, axes = plt.subplots(ncols=2, figsize=(2*fig_width, 3.5), sharey=True)
fig, axes = plt.subplots(ncols=2, figsize=(1.7*fig_width, fig_height), sharey=True)
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.1, hspace=None)

plt.rcParams.update({
    'font.family': 'sans-serif', #helvetica, sans-serif
    #'text.usetex': True,  # Use this only if LaTeX is installed and configured
})

axes[0].plot(x_coord, phi_avg_DNT_st0p3[s.iy0][:],   '-',   label=r'$s_{t0}=0.3$', c='g')
axes[0].plot(x_coord, phi_avg_DNT_dn0p6[s.iy0][:], '-', label=r'$s_{t0}=0.15$', c='b')
axes[0].plot(x_coord, phi_avg_DNT_st0p05[s.iy0][:], '-', label=r'$s_{t0}=0.05$', c='r')


axes[1].plot(x_coord, phi_avg_DPT_st0p3[s.iy0][:], '-',   label=r'$s_{t0}=0.3$', c='g')
axes[1].plot(x_coord, phi_avg_DPT_d0p6[s.iy0][:], '-', label=r'$s_{t0}=0.15$', c='b')
axes[1].plot(x_coord, phi_avg_DPT_st0p05[s.iy0][:],   '-', label=r'$s_{t0}=0.05$', c='r', )




for ax in axes:
    ax.grid(True, which='major', lw=0.5)
    #ax.grid(True, which='major', alpha=0.8, linestyle=':', linewidth=0.5)
    ax.xaxis.set_minor_locator(AutoMinorLocator())
    ax.yaxis.set_minor_locator(AutoMinorLocator())
    ax.tick_params(which='major', direction="in")
    ax.tick_params(which='minor', direction="in")
    #ax.set_xlabel(r'$(r-r_{{sep}})$', rotation=0, size=5, labelpad=1)
    ax.set_xlabel(r'$R/\rho_{s0}$')
    #ax.set_ylabel(r'$n$', rotation=90, size=3, labelpad=1)
    ax.yaxis.get_offset_text().set_fontsize(10)
    # Figure edge setting
    ax.spines["bottom"].set_linewidth(1)
    ax.spines["left"].set_linewidth(1)
    ax.spines["right"].set_linewidth(1)
    ax.spines["top"].set_linewidth(1)
    #ax.set_xlim([450, 495])
    #ax.set_ylim([0.1, 1.7])
    
    #ax.set_yticks(np.arange(0.2, 1.7, 0.4))



axes[0].set_ylabel(r'$\phi$')
#axes[1].set_ylabel(r'$p_e/p_0$')
axes[0].set_title(r'NT $\delta=-0.6$')
axes[1].set_title(r'PT $\delta=+0.6$')


#axes[0].legend(bbox_to_anchor=(0.5, 1), loc='upper right', facecolor='white', framealpha=1)
axes[1].legend(bbox_to_anchor=(1.5, 1), loc='upper right', facecolor='white', framealpha=1 )
#plt.tight_layout()

axes[0].axvline(x=420, lw=1, c='k', ls='--')    
axes[1].axvline(x=510, lw=1, c='k', ls='--')

axes[0].set_xlim([210,440]); #axes[0].set_ylim([0,50])
axes[1].set_xlim([300,530]); axes[1].set_ylim([-1,3])

# Save the figure
dpi_val=300; home_directory = os.path.expanduser('~'); os.chdir(home_directory)
#plt.savefig("OMP_pe.pdf", bbox_inches = 'tight', format='pdf',pad_inches = 0.01, dpi=dpi_val)
